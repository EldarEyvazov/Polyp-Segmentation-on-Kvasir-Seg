# %% [markdown]
# <a href="https://colab.research.google.com/github/EldarEyvazov/PolypSegmentation/blob/main/resunet_without_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, cv2
import numpy as np
import pandas as pd
import random, tqdm
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import albumentations as album
# File processing
from glob import glob
import json
from PIL import Image
from tqdm import tqdm

# Splitting data into train and test sets
from sklearn.model_selection import train_test_split

# Data and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Concatenate, UpSampling2D, Conv2DTranspose, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
pip install tf
# Out:
# Collecting tf
#   Downloading tf-1.0.0.tar.gz (620 bytes)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: tf
#   Building wheel for tf (setup.py) ... done
#   Created wheel for tf: filename=tf-1.0.0-py3-none-any.whl size=1260 sha256=19a0ddaf353889abb40cf755703c2a739cc33b8e89a3eae6cbd6915c0b273239
#   Stored in directory: /root/.cache/pip/wheels/3f/c7/25/9e8467cbf247c674b122fbcf00d8fa558c314731cb511c19c5
# Successfully built tf
# Installing collected packages: tf
# Successfully installed tf-1.0.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np

def read_and_resize_images(img_folder_path, desired_size=(256, 256)):
    images = []
    img_paths = []
    for image_name in sorted(os.listdir(img_folder_path)):
        image_path = os.path.join(img_folder_path, image_name)
        img_paths.append(image_path)

    for img_path in img_paths:
        img = cv2.imread(img_path)
        img = cv2.resize(img, desired_size)
        images.append(img)

    return np.array(images), img_paths

images_folder_path = "/content/drive/MyDrive/Vision Cognitive systems/Kvasir-SEG no augmentation/images"
images, img_p = read_and_resize_images(images_folder_path)

# %%
import os
import cv2
import numpy as np

def read_and_resize_masks(mask_folder_path, desired_size=(256, 256)):
    masks = []
    mask_paths = []
    for mask_name in sorted(os.listdir(mask_folder_path)):
        mask_path = os.path.join(mask_folder_path, mask_name)
        mask_paths.append(mask_path)

    for mask_path in mask_paths:
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, desired_size)
        masks.append(mask)

    return np.array(masks), mask_paths

masks_folder_path = "/content/drive/MyDrive/Vision Cognitive systems/Kvasir-SEG no augmentation/masks"
masks, mask_p = read_and_resize_masks(masks_folder_path)

# %%
def split_data(images, masks, split=0.2):
    total_size = len(images)
    test_size  = int(split * total_size)
    valid_size = int(split * total_size)

    X_train, X_valid = train_test_split(images, test_size=valid_size, random_state=42)
    y_train, y_valid = train_test_split(masks, test_size=valid_size, random_state=42)

    X_train, X_test = train_test_split(X_train, test_size=test_size, random_state=42)
    y_train, y_test = train_test_split(y_train, test_size=test_size, random_state=42)
    return (X_train, y_train), (X_valid, y_valid), (X_test, y_test)

# %%
(X_train, y_train), (X_valid, y_valid), (X_test, y_test) = split_data(images, masks)

print(f"train set size: {len(X_train)}\nvalid set size: {len(X_valid)}\ntest set size:  {len(X_test)}")
# Out:
# train set size: 600
# valid set size: 200
# test set size:  200

# %%
# Find the maximum and minimum pixel values in each channel of the images array
max_pixel_values = np.amax(images, axis=(0, 1, 2))  # Max value for each channel
min_pixel_values = np.amin(images, axis=(0, 1, 2))  # Min value for each channel

print("Maximum pixel values (R, G, B):", max_pixel_values)
print("Minimum pixel values (R, G, B):", min_pixel_values)
# Out:
# Maximum pixel values (R, G, B): [255 255 255]
# Minimum pixel values (R, G, B): [0 0 0]

# %%
# Rescale the pixel values of images to the range [0, 1] for each channel
images = images / 255.0

# Find the maximum and minimum pixel values in each channel of the rescaled images array
max_rescaled_values = np.amax(images, axis=(0, 1, 2))  # Max value for each channel
min_rescaled_values = np.amin(images, axis=(0, 1, 2))  # Min value for each channel

print("Maximum rescaled pixel values (R, G, B):", max_rescaled_values)
print("Minimum rescaled pixel values (R, G, B):", min_rescaled_values)
# Out:
# Maximum rescaled pixel values (R, G, B): [1. 1. 1.]
# Minimum rescaled pixel values (R, G, B): [0. 0. 0.]

# %%
# Find the maximum and minimum pixel values in the masks array
max_pixel_value = np.amax(masks)
min_pixel_value = np.amin(masks)

print("Maximum pixel value for the masks:", max_pixel_value)
print("Minimum pixel value for the masks:", min_pixel_value)
# Out:
# Maximum pixel value for the masks: 255
# Minimum pixel value for the masks: 0

# %%
# Rescale the pixel values of masks to the range [0, 1]
masks = masks / max_pixel_value

# Find the maximum and minimum pixel values in the rescaled masks array
max_rescaled_value = np.amax(masks)
min_rescaled_value = np.amin(masks)

print("Maximum rescaled pixel value for the masks:", max_rescaled_value)
print("Minimum rescaled pixel value for the masks:", min_rescaled_value)
# Out:
# Maximum rescaled pixel value for the masks: 1.0
# Minimum rescaled pixel value for the masks: 0.0

# %%
import matplotlib.pyplot as plt
import random


# Set up the figure for plotting
fig, axes = plt.subplots(2, 5, figsize=(15, 6))

# Randomly select 5 indices
random_indices = random.sample(range(len(images)), 5)

# Plot the images and masks
for i, idx in enumerate(random_indices):
    # Plot the image
    axes[0, i].imshow(images[idx])
    axes[0, i].set_title("Image")
    axes[0, i].axis("off")

    # Plot the mask
    axes[1, i].imshow(masks[idx], cmap='gray')
    axes[1, i].set_title("Mask")
    axes[1, i].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # ResUnet

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import backend as K

# Define custom metrics
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection+smooth ) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    total = K.sum(y_true_f) + K.sum(y_pred_f)
    union = total - intersection
    return (intersection+smooth ) / (union + smooth)

# Define the dice loss function
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true = K.cast(y_true, 'float32')  # Ensure y_true is float32
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
# Ensure masks are binary
y_train = (y_train > 0).astype('float32')
y_valid = (y_valid > 0).astype('float32')
y_test = (y_test > 0).astype('float32')

# %% [markdown]
# # batch size 12

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, Input, BatchNormalization, Activation, Add, MaxPooling2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def residual_block(x, filters, kernel_size=3):
    shortcut = Conv2D(filters, kernel_size=1, padding='same', kernel_regularizer=l2(1e-4))(x)
    shortcut = BatchNormalization()(shortcut)
    x = Conv2D(filters, kernel_size, padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, kernel_size, padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

def encoder_block(x, filters):
    x = residual_block(x, filters)
    p = MaxPooling2D((2, 2))(x)
    return x, p

def decoder_block(x, skip_features, filters):
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(filters, kernel_size=1, padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = concatenate([x, skip_features])
    x = residual_block(x, filters)
    return x

def ResUNet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    # Bridge
    b1 = residual_block(p4, 512)

    # Decoder
    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(num_classes, 1, padding='same', activation='sigmoid')(d4)

    model = Model(inputs, outputs, name='ResUNet')
    return model

# Define the input parameters
input_shape = (256, 256, 3)
num_classes = 1

# Create the model
model = ResUNet(input_shape, num_classes)

# Print the model summary
model.summary()
# Out:
# Model: "ResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_97 (Conv2D)          (None, 256, 256, 32)         896       ['input_4[0][0]']
#
#  batch_normalization_94 (Ba  (None, 256, 256, 32)         128       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_66 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 256, 256, 32)         9248      ['activation_66[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 256, 256, 32)         128       ['input_4[0][0]']
#
#  batch_normalization_95 (Ba  (None, 256, 256, 32)         128       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  batch_normalization_93 (Ba  (None, 256, 256, 32)         128       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  add_27 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ',
#                                                                      'batch_normalization_93[0][0]
#                                                                     ']
#
#  activation_67 (Activation)  (None, 256, 256, 32)         0         ['add_27[0][0]']
#
#  max_pooling2d_12 (MaxPooli  (None, 128, 128, 32)         0         ['activation_67[0][0]']
#  ng2D)
#
#  conv2d_100 (Conv2D)         (None, 128, 128, 64)         18496     ['max_pooling2d_12[0][0]']
#
#  batch_normalization_97 (Ba  (None, 128, 128, 64)         256       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  activation_68 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_101 (Conv2D)         (None, 128, 128, 64)         36928     ['activation_68[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 128, 128, 64)         2112      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_98 (Ba  (None, 128, 128, 64)         256       ['conv2d_101[0][0]']
#  tchNormalization)
#
#  batch_normalization_96 (Ba  (None, 128, 128, 64)         256       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  add_28 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_98[0][0]
#                                                                     ',
#                                                                      'batch_normalization_96[0][0]
#                                                                     ']
#
#  activation_69 (Activation)  (None, 128, 128, 64)         0         ['add_28[0][0]']
#
#  max_pooling2d_13 (MaxPooli  (None, 64, 64, 64)           0         ['activation_69[0][0]']
#  ng2D)
#
#  conv2d_103 (Conv2D)         (None, 64, 64, 128)          73856     ['max_pooling2d_13[0][0]']
#
#  batch_normalization_100 (B  (None, 64, 64, 128)          512       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_70 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  conv2d_104 (Conv2D)         (None, 64, 64, 128)          147584    ['activation_70[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 64, 64, 128)          8320      ['max_pooling2d_13[0][0]']
#
#  batch_normalization_101 (B  (None, 64, 64, 128)          512       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_99 (Ba  (None, 64, 64, 128)          512       ['conv2d_102[0][0]']
#  tchNormalization)
#
#  add_29 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_101[0][0
#                                                                     ]',
#                                                                      'batch_normalization_99[0][0]
#                                                                     ']
#
#  activation_71 (Activation)  (None, 64, 64, 128)          0         ['add_29[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 32, 32, 128)          0         ['activation_71[0][0]']
#  ng2D)
#
#  conv2d_106 (Conv2D)         (None, 32, 32, 256)          295168    ['max_pooling2d_14[0][0]']
#
#  batch_normalization_103 (B  (None, 32, 32, 256)          1024      ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_72 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  conv2d_107 (Conv2D)         (None, 32, 32, 256)          590080    ['activation_72[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 32, 32, 256)          33024     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_104 (B  (None, 32, 32, 256)          1024      ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_102 (B  (None, 32, 32, 256)          1024      ['conv2d_105[0][0]']
#  atchNormalization)
#
#  add_30 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_104[0][0
#                                                                     ]',
#                                                                      'batch_normalization_102[0][0
#                                                                     ]']
#
#  activation_73 (Activation)  (None, 32, 32, 256)          0         ['add_30[0][0]']
#
#  max_pooling2d_15 (MaxPooli  (None, 16, 16, 256)          0         ['activation_73[0][0]']
#  ng2D)
#
#  conv2d_109 (Conv2D)         (None, 16, 16, 512)          1180160   ['max_pooling2d_15[0][0]']
#
#  batch_normalization_106 (B  (None, 16, 16, 512)          2048      ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_74 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_106[0][0
#                                                                     ]']
#
#  conv2d_110 (Conv2D)         (None, 16, 16, 512)          2359808   ['activation_74[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 16, 16, 512)          131584    ['max_pooling2d_15[0][0]']
#
#  batch_normalization_107 (B  (None, 16, 16, 512)          2048      ['conv2d_110[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 16, 16, 512)          2048      ['conv2d_108[0][0]']
#  atchNormalization)
#
#  add_31 (Add)                (None, 16, 16, 512)          0         ['batch_normalization_107[0][0
#                                                                     ]',
#                                                                      'batch_normalization_105[0][0
#                                                                     ]']
#
#  activation_75 (Activation)  (None, 16, 16, 512)          0         ['add_31[0][0]']
#
#  up_sampling2d_12 (UpSampli  (None, 32, 32, 512)          0         ['activation_75[0][0]']
#  ng2D)
#
#  conv2d_111 (Conv2D)         (None, 32, 32, 256)          131328    ['up_sampling2d_12[0][0]']
#
#  batch_normalization_108 (B  (None, 32, 32, 256)          1024      ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_76 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_108[0][0
#                                                                     ]']
#
#  concatenate_12 (Concatenat  (None, 32, 32, 512)          0         ['activation_76[0][0]',
#  e)                                                                  'activation_73[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 32, 32, 256)          1179904   ['concatenate_12[0][0]']
#
#  batch_normalization_110 (B  (None, 32, 32, 256)          1024      ['conv2d_113[0][0]']
#  atchNormalization)
#
#  activation_77 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_110[0][0
#                                                                     ]']
#
#  conv2d_114 (Conv2D)         (None, 32, 32, 256)          590080    ['activation_77[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 32, 32, 256)          131328    ['concatenate_12[0][0]']
#
#  batch_normalization_111 (B  (None, 32, 32, 256)          1024      ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_109 (B  (None, 32, 32, 256)          1024      ['conv2d_112[0][0]']
#  atchNormalization)
#
#  add_32 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_111[0][0
#                                                                     ]',
#                                                                      'batch_normalization_109[0][0
#                                                                     ]']
#
#  activation_78 (Activation)  (None, 32, 32, 256)          0         ['add_32[0][0]']
#
#  up_sampling2d_13 (UpSampli  (None, 64, 64, 256)          0         ['activation_78[0][0]']
#  ng2D)
#
#  conv2d_115 (Conv2D)         (None, 64, 64, 128)          32896     ['up_sampling2d_13[0][0]']
#
#  batch_normalization_112 (B  (None, 64, 64, 128)          512       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  activation_79 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_112[0][0
#                                                                     ]']
#
#  concatenate_13 (Concatenat  (None, 64, 64, 256)          0         ['activation_79[0][0]',
#  e)                                                                  'activation_71[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 64, 64, 128)          295040    ['concatenate_13[0][0]']
#
#  batch_normalization_114 (B  (None, 64, 64, 128)          512       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  activation_80 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_114[0][0
#                                                                     ]']
#
#  conv2d_118 (Conv2D)         (None, 64, 64, 128)          147584    ['activation_80[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 64, 64, 128)          32896     ['concatenate_13[0][0]']
#
#  batch_normalization_115 (B  (None, 64, 64, 128)          512       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_113 (B  (None, 64, 64, 128)          512       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  add_33 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_115[0][0
#                                                                     ]',
#                                                                      'batch_normalization_113[0][0
#                                                                     ]']
#
#  activation_81 (Activation)  (None, 64, 64, 128)          0         ['add_33[0][0]']
#
#  up_sampling2d_14 (UpSampli  (None, 128, 128, 128)        0         ['activation_81[0][0]']
#  ng2D)
#
#  conv2d_119 (Conv2D)         (None, 128, 128, 64)         8256      ['up_sampling2d_14[0][0]']
#
#  batch_normalization_116 (B  (None, 128, 128, 64)         256       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_82 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_116[0][0
#                                                                     ]']
#
#  concatenate_14 (Concatenat  (None, 128, 128, 128)        0         ['activation_82[0][0]',
#  e)                                                                  'activation_69[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 128, 128, 64)         73792     ['concatenate_14[0][0]']
#
#  batch_normalization_118 (B  (None, 128, 128, 64)         256       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  activation_83 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_118[0][0
#                                                                     ]']
#
#  conv2d_122 (Conv2D)         (None, 128, 128, 64)         36928     ['activation_83[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 128, 128, 64)         8256      ['concatenate_14[0][0]']
#
#  batch_normalization_119 (B  (None, 128, 128, 64)         256       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 128, 128, 64)         256       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  add_34 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_119[0][0
#                                                                     ]',
#                                                                      'batch_normalization_117[0][0
#                                                                     ]']
#
#  activation_84 (Activation)  (None, 128, 128, 64)         0         ['add_34[0][0]']
#
#  up_sampling2d_15 (UpSampli  (None, 256, 256, 64)         0         ['activation_84[0][0]']
#  ng2D)
#
#  conv2d_123 (Conv2D)         (None, 256, 256, 32)         2080      ['up_sampling2d_15[0][0]']
#
#  batch_normalization_120 (B  (None, 256, 256, 32)         128       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  activation_85 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_120[0][0
#                                                                     ]']
#
#  concatenate_15 (Concatenat  (None, 256, 256, 64)         0         ['activation_85[0][0]',
#  e)                                                                  'activation_67[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 256, 256, 32)         18464     ['concatenate_15[0][0]']
#
#  batch_normalization_122 (B  (None, 256, 256, 32)         128       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  activation_86 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_122[0][0
#                                                                     ]']
#
#  conv2d_126 (Conv2D)         (None, 256, 256, 32)         9248      ['activation_86[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 256, 256, 32)         2080      ['concatenate_15[0][0]']
#
#  batch_normalization_123 (B  (None, 256, 256, 32)         128       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  batch_normalization_121 (B  (None, 256, 256, 32)         128       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  add_35 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_123[0][0
#                                                                     ]',
#                                                                      'batch_normalization_121[0][0
#                                                                     ]']
#
#  activation_87 (Activation)  (None, 256, 256, 32)         0         ['add_35[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 256, 256, 1)          33        ['activation_87[0][0]']
#
# ==================================================================================================
# Total params: 7607169 (29.02 MB)
# Trainable params: 7597377 (28.98 MB)
# Non-trainable params: 9792 (38.25 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import csv
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras import backend as K

# Custom callback to save metrics to CSV
class CSVLogger(Callback):
    def __init__(self, filename, separator=',', append=False):
        super(CSVLogger, self).__init__()
        self.sep = separator
        self.filename = filename
        self.append = append
        self.csv_file = None
        self.writer = None
        self.keys = None
        self.append_header = True

    def on_train_begin(self, logs=None):
        if self.append:
            if tf.io.gfile.exists(self.filename):
                with open(self.filename, 'r') as f:
                    self.append_header = not bool(len(f.readline()))
            mode = 'a'
        else:
            mode = 'w'

        self.csv_file = open(self.filename, mode, newline='')
        self.writer = csv.DictWriter(self.csv_file, fieldnames=None, delimiter=self.sep)
        self.keys = None

    def on_epoch_end(self, epoch, logs=None):
        if not self.keys:
            self.keys = sorted(logs.keys())
            self.writer.fieldnames = ['epoch'] + self.keys
            if self.append_header:
                self.writer.writeheader()

        row_dict = {'epoch': epoch}
        row_dict.update((key, logs[key]) for key in self.keys)
        self.writer.writerow(row_dict)
        self.csv_file.flush()

    def on_train_end(self, logs=None):
        if self.csv_file:
            self.csv_file.close()
            self.csv_file = None
            self.writer = None
            self.keys = None

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

def train_model(model, train_data, val_data, batch_size, epochs, save_path, csv_log_path):
    # Define early stopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Define learning rate scheduler callback
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-9, verbose=1)

    # Custom CSV logger callback
    csv_logger = CSVLogger(filename=csv_log_path)

    # Compile the model (assuming binary segmentation)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
                  loss=dice_loss,
                  metrics=['accuracy',iou_coef, dice_coef])

    # Train the model
    history = model.fit(train_data,
                        validation_data=val_data,
                        epochs=epochs,
                        callbacks=[early_stopping, lr_scheduler, csv_logger])

    # Save the model in the SavedModel format
    model.save(save_path)

    return history

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(12).prefetch(tf.data.experimental.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((X_valid, y_valid)).batch(12).prefetch(tf.data.experimental.AUTOTUNE)

# Define the input parameters
input_shape = (256, 256, 3)
num_classes = 1

# Create the model
model = ResUNet(input_shape, num_classes)

# Paths for saving metrics and the model
csv_log_path = '/content/drive/MyDrive/Vision Cognitive systems/Kvasir-SEG no augmentation/results/training_metrics_resunet_noaug.csv'
save_path = '/content/drive/MyDrive/Vision Cognitive systems/Kvasir-SEG no augmentation/results/resunet_noaug'
history = train_model(model, train_data=train_dataset, val_data=val_dataset, batch_size=12, epochs=50, save_path=save_path, csv_log_path=csv_log_path)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 35s 395ms/step - loss: 0.9909 - accuracy: 0.7367 - iou_coef: 0.3002 - dice_coef: 0.4578 - val_loss: 1.0916 - val_accuracy: 0.3930 - val_iou_coef: 0.2069 - val_dice_coef: 0.3396 - lr: 3.0000e-04
# Epoch 2/50
# 50/50 [==============================] - 19s 390ms/step - loss: 0.8789 - accuracy: 0.8249 - iou_coef: 0.3700 - dice_coef: 0.5379 - val_loss: 0.9804 - val_accuracy: 0.6271 - val_iou_coef: 0.2734 - val_dice_coef: 0.4251 - lr: 3.0000e-04
# Epoch 3/50
# 50/50 [==============================] - 19s 378ms/step - loss: 0.8014 - accuracy: 0.8518 - iou_coef: 0.4206 - dice_coef: 0.5904 - val_loss: 0.8481 - val_accuracy: 0.7866 - val_iou_coef: 0.3686 - val_dice_coef: 0.5330 - lr: 3.0000e-04
# Epoch 4/50
# 50/50 [==============================] - 19s 372ms/step - loss: 0.7511 - accuracy: 0.8686 - iou_coef: 0.4490 - dice_coef: 0.6178 - val_loss: 0.7744 - val_accuracy: 0.8533 - val_iou_coef: 0.4186 - val_dice_coef: 0.5841 - lr: 3.0000e-04
# Epoch 5/50
# 50/50 [==============================] - 19s 372ms/step - loss: 0.7162 - accuracy: 0.8753 - iou_coef: 0.4647 - dice_coef: 0.6324 - val_loss: 0.7431 - val_accuracy: 0.8481 - val_iou_coef: 0.4306 - val_dice_coef: 0.5960 - lr: 3.0000e-04
# Epoch 6/50
# 50/50 [==============================] - 19s 378ms/step - loss: 0.6741 - accuracy: 0.8865 - iou_coef: 0.4905 - dice_coef: 0.6565 - val_loss: 0.7177 - val_accuracy: 0.8627 - val_iou_coef: 0.4407 - val_dice_coef: 0.6044 - lr: 3.0000e-04
# Epoch 7/50
# 50/50 [==============================] - 19s 379ms/step - loss: 0.6480 - accuracy: 0.8925 - iou_coef: 0.5026 - dice_coef: 0.6669 - val_loss: 0.7215 - val_accuracy: 0.8246 - val_iou_coef: 0.4216 - val_dice_coef: 0.5868 - lr: 3.0000e-04
# Epoch 8/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.6168 - accuracy: 0.8979 - iou_coef: 0.5226 - dice_coef: 0.6845 - val_loss: 0.6826 - val_accuracy: 0.8434 - val_iou_coef: 0.4495 - val_dice_coef: 0.6136 - lr: 3.0000e-04
# Epoch 9/50
# 50/50 [==============================] - 19s 375ms/step - loss: 0.5971 - accuracy: 0.9002 - iou_coef: 0.5318 - dice_coef: 0.6923 - val_loss: 0.6737 - val_accuracy: 0.8849 - val_iou_coef: 0.4466 - val_dice_coef: 0.6101 - lr: 3.0000e-04
# Epoch 10/50
# 50/50 [==============================] - 19s 376ms/step - loss: 0.5589 - accuracy: 0.9112 - iou_coef: 0.5645 - dice_coef: 0.7197 - val_loss: 0.6325 - val_accuracy: 0.8861 - val_iou_coef: 0.4817 - val_dice_coef: 0.6411 - lr: 3.0000e-04
# Epoch 11/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.5386 - accuracy: 0.9136 - iou_coef: 0.5777 - dice_coef: 0.7298 - val_loss: 0.6257 - val_accuracy: 0.8950 - val_iou_coef: 0.4770 - val_dice_coef: 0.6370 - lr: 3.0000e-04
# Epoch 12/50
# 50/50 [==============================] - 19s 378ms/step - loss: 0.5100 - accuracy: 0.9210 - iou_coef: 0.6015 - dice_coef: 0.7493 - val_loss: 0.6033 - val_accuracy: 0.8732 - val_iou_coef: 0.4933 - val_dice_coef: 0.6526 - lr: 3.0000e-04
# Epoch 13/50
# 50/50 [==============================] - 19s 376ms/step - loss: 0.4877 - accuracy: 0.9254 - iou_coef: 0.6205 - dice_coef: 0.7635 - val_loss: 0.8320 - val_accuracy: 0.8729 - val_iou_coef: 0.2681 - val_dice_coef: 0.4111 - lr: 3.0000e-04
# Epoch 14/50
# 50/50 [==============================] - 19s 376ms/step - loss: 0.4565 - accuracy: 0.9333 - iou_coef: 0.6519 - dice_coef: 0.7869 - val_loss: 0.6481 - val_accuracy: 0.8981 - val_iou_coef: 0.4278 - val_dice_coef: 0.5914 - lr: 3.0000e-04
# Epoch 15/50
# 50/50 [==============================] - ETA: 0s - loss: 0.4455 - accuracy: 0.9344 - iou_coef: 0.6573 - dice_coef: 0.7911
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# 50/50 [==============================] - 19s 376ms/step - loss: 0.4455 - accuracy: 0.9344 - iou_coef: 0.6573 - dice_coef: 0.7911 - val_loss: 0.7659 - val_accuracy: 0.8779 - val_iou_coef: 0.3142 - val_dice_coef: 0.4660 - lr: 3.0000e-04
# Epoch 16/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.4055 - accuracy: 0.9461 - iou_coef: 0.7086 - dice_coef: 0.8273 - val_loss: 0.5659 - val_accuracy: 0.9125 - val_iou_coef: 0.5097 - val_dice_coef: 0.6655 - lr: 6.0000e-05
# Epoch 17/50
# 50/50 [==============================] - 19s 376ms/step - loss: 0.3789 - accuracy: 0.9539 - iou_coef: 0.7450 - dice_coef: 0.8521 - val_loss: 0.5678 - val_accuracy: 0.9124 - val_iou_coef: 0.5063 - val_dice_coef: 0.6617 - lr: 6.0000e-05
# Epoch 18/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3629 - accuracy: 0.9583 - iou_coef: 0.7667 - dice_coef: 0.8663 - val_loss: 0.5412 - val_accuracy: 0.9154 - val_iou_coef: 0.5354 - val_dice_coef: 0.6869 - lr: 6.0000e-05
# Epoch 19/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3490 - accuracy: 0.9620 - iou_coef: 0.7856 - dice_coef: 0.8784 - val_loss: 0.5713 - val_accuracy: 0.9111 - val_iou_coef: 0.4990 - val_dice_coef: 0.6548 - lr: 6.0000e-05
# Epoch 20/50
# 50/50 [==============================] - 19s 376ms/step - loss: 0.3388 - accuracy: 0.9646 - iou_coef: 0.7989 - dice_coef: 0.8868 - val_loss: 0.5429 - val_accuracy: 0.9144 - val_iou_coef: 0.5298 - val_dice_coef: 0.6820 - lr: 6.0000e-05
# Epoch 21/50
# 50/50 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.9664 - iou_coef: 0.8088 - dice_coef: 0.8929
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# 50/50 [==============================] - 19s 376ms/step - loss: 0.3309 - accuracy: 0.9664 - iou_coef: 0.8088 - dice_coef: 0.8929 - val_loss: 0.5435 - val_accuracy: 0.9146 - val_iou_coef: 0.5256 - val_dice_coef: 0.6787 - lr: 6.0000e-05
# Epoch 22/50
# 50/50 [==============================] - 19s 378ms/step - loss: 0.3221 - accuracy: 0.9688 - iou_coef: 0.8213 - dice_coef: 0.9006 - val_loss: 0.5299 - val_accuracy: 0.9170 - val_iou_coef: 0.5412 - val_dice_coef: 0.6921 - lr: 1.2000e-05
# Epoch 23/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3174 - accuracy: 0.9702 - iou_coef: 0.8284 - dice_coef: 0.9050 - val_loss: 0.5114 - val_accuracy: 0.9189 - val_iou_coef: 0.5627 - val_dice_coef: 0.7105 - lr: 1.2000e-05
# Epoch 24/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3142 - accuracy: 0.9711 - iou_coef: 0.8332 - dice_coef: 0.9078 - val_loss: 0.5070 - val_accuracy: 0.9183 - val_iou_coef: 0.5675 - val_dice_coef: 0.7149 - lr: 1.2000e-05
# Epoch 25/50
# 50/50 [==============================] - 19s 378ms/step - loss: 0.3113 - accuracy: 0.9718 - iou_coef: 0.8372 - dice_coef: 0.9103 - val_loss: 0.5046 - val_accuracy: 0.9178 - val_iou_coef: 0.5698 - val_dice_coef: 0.7170 - lr: 1.2000e-05
# Epoch 26/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3087 - accuracy: 0.9725 - iou_coef: 0.8410 - dice_coef: 0.9125 - val_loss: 0.5048 - val_accuracy: 0.9175 - val_iou_coef: 0.5691 - val_dice_coef: 0.7165 - lr: 1.2000e-05
# Epoch 27/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3066 - accuracy: 0.9730 - iou_coef: 0.8438 - dice_coef: 0.9142 - val_loss: 0.5065 - val_accuracy: 0.9171 - val_iou_coef: 0.5667 - val_dice_coef: 0.7143 - lr: 1.2000e-05
# Epoch 28/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3043 - accuracy: 0.9736 - iou_coef: 0.8470 - dice_coef: 0.9161 - val_loss: 0.5029 - val_accuracy: 0.9169 - val_iou_coef: 0.5704 - val_dice_coef: 0.7176 - lr: 1.2000e-05
# Epoch 29/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3022 - accuracy: 0.9741 - iou_coef: 0.8499 - dice_coef: 0.9178 - val_loss: 0.5020 - val_accuracy: 0.9167 - val_iou_coef: 0.5710 - val_dice_coef: 0.7182 - lr: 1.2000e-05
# Epoch 30/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.3000 - accuracy: 0.9747 - iou_coef: 0.8529 - dice_coef: 0.9196 - val_loss: 0.5011 - val_accuracy: 0.9171 - val_iou_coef: 0.5716 - val_dice_coef: 0.7186 - lr: 1.2000e-05
# Epoch 31/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.2979 - accuracy: 0.9752 - iou_coef: 0.8558 - dice_coef: 0.9213 - val_loss: 0.5041 - val_accuracy: 0.9171 - val_iou_coef: 0.5676 - val_dice_coef: 0.7151 - lr: 1.2000e-05
# Epoch 32/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.2960 - accuracy: 0.9756 - iou_coef: 0.8582 - dice_coef: 0.9227 - val_loss: 0.5015 - val_accuracy: 0.9164 - val_iou_coef: 0.5698 - val_dice_coef: 0.7173 - lr: 1.2000e-05
# Epoch 33/50
# 50/50 [==============================] - ETA: 0s - loss: 0.2942 - accuracy: 0.9761 - iou_coef: 0.8606 - dice_coef: 0.9241
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# 50/50 [==============================] - 19s 378ms/step - loss: 0.2942 - accuracy: 0.9761 - iou_coef: 0.8606 - dice_coef: 0.9241 - val_loss: 0.5057 - val_accuracy: 0.9165 - val_iou_coef: 0.5644 - val_dice_coef: 0.7126 - lr: 1.2000e-05
# Epoch 34/50
# 50/50 [==============================] - 19s 377ms/step - loss: 0.2922 - accuracy: 0.9766 - iou_coef: 0.8636 - dice_coef: 0.9259 - val_loss: 0.5024 - val_accuracy: 0.9159 - val_iou_coef: 0.5679 - val_dice_coef: 0.7159 - lr: 2.4000e-06
# Epoch 35/50
# 50/50 [==============================] - 19s 379ms/step - loss: 0.2917 - accuracy: 0.9767 - iou_coef: 0.8643 - dice_coef: 0.9263 - val_loss: 0.5024 - val_accuracy: 0.9155 - val_iou_coef: 0.5677 - val_dice_coef: 0.7158 - lr: 2.4000e-06

# %% [markdown]
# plotting the results by reading .csv file

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the CSV file into a DataFrame
csv_log_path = '/content/drive/MyDrive/Vision Cognitive systems/Kvasir-SEG no augmentation/results/resunet_noaug/training_metrics_resunet_noaug.csv'
df = pd.read_csv(csv_log_path)

# Extract metrics from the DataFrame
epochs = df['epoch'] + 1
loss = df['loss']
val_loss = df['val_loss']
accuracy = df['accuracy']
val_accuracy = df['val_accuracy']
iou = df['iou_coef']
val_iou = df['val_iou_coef']
dice = df['dice_coef']
val_dice = df['val_dice_coef']

# Plot training and validation metrics
plt.figure(figsize=(20, 6))

# Subplot 1: Loss
plt.subplot(1, 3, 1)
plt.plot(epochs, loss, label='Training Loss', color='#1f77b4')
plt.plot(epochs, val_loss, label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(False)

# Subplot 2: Accuracy
plt.subplot(1, 3, 2)
plt.plot(epochs, accuracy, label='Training Accuracy', color='#1f77b4')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', color='orange')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(False)

# Subplot 3: IoU and Dice Coefficient
plt.subplot(1, 3, 3)
plt.plot(epochs, iou, label='Training IoU', color='#1f77b4', linestyle='--')
plt.plot(epochs, val_iou, label='Validation IoU', color='orange', linestyle='--')
plt.plot(epochs, dice, label='Training Dice Coefficient', color='#1f77b4')
plt.plot(epochs, val_dice, label='Validation Dice Coefficient', color='orange')
plt.title('Training and Validation IoU & Dice Coefficient')
plt.xlabel('Epochs')
plt.ylabel('Coefficient')
plt.legend()
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Paths for the CSV log file
csv_log_path = '/content/drive/MyDrive/Vision Cognitive systems/Kvasir-SEG no augmentation/results/resunet_noaug/training_metrics_resunet_noaug.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_log_path)

# Extract metrics from the DataFrame
epochs = df['epoch'] + 1
train_loss = df['loss']
train_accuracy = df['accuracy']
train_iou = df['iou_coef']
train_dice = df['dice_coef']

# Evaluate the model on the test set
loss, accuracy, iou, dice = model.evaluate(X_test, y_test, batch_size=8)
print(f'Test Loss: {loss}\nTest Accuracy: {accuracy}\nIoU: {iou}\nDice: {dice}')

# Generate predictions on the test set
predictions = model.predict(X_test, batch_size=8)

# Create lists for test metrics to match the number of epochs
test_loss_list = [loss] * len(epochs)
test_accuracy_list = [accuracy] * len(epochs)
test_iou_list = [iou] * len(epochs)
test_dice_list = [dice] * len(epochs)

# Plot training and test metrics
plt.figure(figsize=(20, 6))

# Subplot 1: Loss
plt.subplot(1, 3, 1)
plt.plot(epochs, train_loss, label='Training Loss', color="#1f77b4")
plt.plot(epochs, test_loss_list, label='Test Loss', color='orange', linestyle='--')
plt.title('Training and Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(False)

# Subplot 2: Accuracy
plt.subplot(1, 3, 2)
plt.plot(epochs, train_accuracy, label='Training Accuracy', color='#1f77b4')
plt.plot(epochs, test_accuracy_list, label='Test Accuracy', color='orange', linestyle='--')
plt.title('Training and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(False)

# Subplot 3: IoU and Dice Coefficient
plt.subplot(1, 3, 3)
plt.plot(epochs, train_iou, label='Training IoU', color='#1f77b4', linestyle='--')
plt.plot(epochs, test_iou_list, label='Test IoU', color='orange', linestyle='--')
plt.plot(epochs, train_dice, label='Training Dice Coefficient', color='#1f77b4')
plt.plot(epochs, test_dice_list, label='Test Dice Coefficient', color='orange')
plt.title('Training and Test IoU & Dice Coefficient')
plt.xlabel('Epochs')
plt.ylabel('Coefficient')
plt.legend()
plt.grid(False)

plt.tight_layout()
plt.subplots_adjust(top=0.9)  # Adjust the top margin
plt.show()
# Out:
# 25/25 [==============================] - 2s 72ms/step - loss: 0.4816 - accuracy: 0.9251 - iou_coef: 0.5935 - dice_coef: 0.7378
# Test Loss: 0.48155564069747925
# Test Accuracy: 0.9250532388687134
# IoU: 0.593515157699585
# Dice: 0.7378390431404114
# 25/25 [==============================] - 2s 69ms/step
